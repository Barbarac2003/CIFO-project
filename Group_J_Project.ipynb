# %% [markdown]
# <h1 align="center" style="margin: 0; font-size: 36px;">Computational Intelligence for Optimization</h1>
# <br>
# <h1 align="center" style="margin: 0; font-size: 30px;">Music Festival Lineup Optimization</h1>
#
# <br>
#
# **Group members:**<br>
# Bárbara Capitão - 20211532@novaims.unl.pt <br>
# Carolina Silvestre - 20211512@novaims.unl.pt <br>
# Francisco Pontes -  <br>
# Lara Leandro - 20211632@novaims.unl.pt <br>

# %% [markdown]
# ### Objective
# Design the optimal festival lineup by assigning each artist to a specific stage and time slot, optimizing three key criteria:
#
# 1. **Prime Slot Popularity**
#    Maximize the total popularity of artists scheduled in the final time slot (prime slot) on each stage.
#
# 2. **Genre Diversity**
#    Maximize the diversity of musical genres across stages in each time slot. For every time slot, compute the average number of unique genres, normalized by the number of stages.
#
# 3. **Conflict Penalty**
#    Minimize fan base conflicts by avoiding scheduling artists with overlapping fan bases at the same time on different stages. This penalty is calculated using a provided pairwise conflict matrix.
#
# ---
#
# ### Constraints
# - Each artist must be assigned to **exactly one stage and one time slot**.
# - All stages must have **the same number of time slots**.
# - All time slots occur **simultaneously** across all stages.
# - No artist can be scheduled more than once or left unassigned.
#
# ---
#
# ### Representation
# - The lineup is modeled as a 2D matrix:
#   `lineup[stage][slot] = artist_id`
# - There are **5 stages and 7 time slots**, for a total of **35 artists**.
#
# ---

# %% [markdown]
# ## Imports and Setup

# %%
import numpy as np
import pandas as pd
import random
from collections import defaultdict

random.seed(42)
np.random.seed(42)

# %% [markdown]
# ## Load Data

# %%
artists = pd.read_csv('artists(in).csv')

# %%
conflict_matrix = pd.read_csv('conflicts(in).csv', index_col=0)

# %%
artists.rename(columns={'Unnamed: 0': 'artist_id'}, inplace=True)
artists.set_index('artist_id', inplace=True)

# %%
artists
# Out:
#                                name       genre  popularity
# artist_id
# 0                     Midnight Echo        Rock          75
# 1                       Solar Flare  Electronic          78
# 2                      Velvet Pulse        Jazz          35
# 3                      Neon Reverie  Electronic         100
# 4                   The Silver Owls   Classical          85
# 5                      Echo Chamber  Electronic          98
# 6                      Aurora Skies         Pop          75
# 7                     Static Mirage        Rock          94
# 8                   Crimson Harmony   Classical          20
# 9                    Deep Resonance        Jazz          90
# 10              The Wandering Notes        Jazz          84
# 11                   Phantom Groove     Hip-Hop          47
# 12                     Blue Horizon         Pop          51
# 13                   Lunar Spectrum        Rock          99
# 14                 Synthwave Saints        Rock          94
# 15                     Golden Ember        Rock          61
# 16                   Mystic Rhythms   Classical          78
# 17                 Nightfall Sonata   Classical          84
# 18               Velvet Underground        Rock          72
# 19                      Astral Tide  Electronic          69
# 20               The Sonic Drifters        Rock          88
# 21                 Celestial Voyage  Electronic          95
# 22                     Quantum Beat     Hip-Hop          96
# 23                Electric Serpents  Electronic          99
# 24                   Shadow Cadence        Jazz          66
# 25                   Rhythm Alchemy        Jazz          94
# 26            Cloud Nine Collective         Pop          97
# 27                  Hypnotic Echoes        Rock          77
# 28         The Polyrhythm Syndicate        Jazz          66
# 29              Harmonic Dissonance   Classical          96
# 30                     Turbo Vortex        Rock          53
# 31                  The Jazz Nomads        Jazz          64
# 32          The Bassline Architects     Hip-Hop          61
# 33                 Cosmic Frequency        Rock          53
# 34               Parallel Dimension  Electronic          58

# %%
conflict_matrix
# Out:
#                           Midnight Echo  Solar Flare  Velvet Pulse  \
# Midnight Echo                      0.00         0.00          0.00
# Solar Flare                        0.00         0.00          0.00
# Velvet Pulse                       0.00         0.00          0.00
# Neon Reverie                       0.20         1.00          1.00
# The Silver Owls                    0.50         0.00          0.50
# Echo Chamber                       0.00         1.00          0.00
# Aurora Skies                       0.80         0.00          0.65
# Static Mirage                      1.00         1.00          1.00
# Crimson Harmony                    0.20         0.00          0.50
# Deep Resonance                     0.50         0.65          1.00
# The Wandering Notes                0.00         0.00          0.90
# Phantom Groove                     0.20         0.00          0.20
# Blue Horizon                       0.90         0.65          0.20
# Lunar Spectrum                     0.90         0.20          0.80
# Synthwave Saints                   1.00         0.00          0.20
# Golden Ember                       0.90         0.00          0.40
# Mystic Rhythms                     1.00         0.20          0.50
# Nightfall Sonata                   0.20         0.15          0.50
# Velvet Underground                 1.00         1.00          1.00
# Astral Tide                        0.00         0.90          0.20
# The Sonic Drifters                 0.90         0.40          0.65
# Celestial Voyage                   0.00         1.00          1.00
# Quantum Beat                       0.20         0.20          0.80
# Electric Serpents                  0.00         0.90          0.65
# Shadow Cadence                     0.20         0.20          0.90
# Rhythm Alchemy                     0.20         0.20          1.00
# Cloud Nine Collective              0.80         0.65          1.00
# Hypnotic Echoes                    1.00         0.00          0.40
# The Polyrhythm Syndicate           1.00         0.65          1.00
# Harmonic Dissonance                0.65         0.40          0.70
# Turbo Vortex                       1.00         0.40          0.00
# The Jazz Nomads                    0.40         0.40          1.00
# The Bassline Architects            0.40         0.00          0.15
# Cosmic Frequency                   1.00         0.00          1.00
# Parallel Dimension                 0.20         1.00          0.40
#
#                           Neon Reverie  The Silver Owls  Echo Chamber  \
# Midnight Echo                     0.20             0.50          0.00
# Solar Flare                       1.00             0.00          1.00
# Velvet Pulse                      1.00             0.50          0.00
# Neon Reverie                      0.00             0.20          0.90
# The Silver Owls                   0.20             0.00          1.00
# Echo Chamber                      0.90             1.00          0.00
# Aurora Skies                      0.20             0.00          0.50
# Static Mirage                     1.00             1.00          1.00
# Crimson Harmony                   0.00             0.90          0.80
# Deep Resonance                    1.00             0.00          0.65
# The Wandering Notes               0.80             0.00          0.00
# Phantom Groove                    0.80             0.00          0.65
# Blue Horizon                      0.50             0.00          0.15
# Lunar Spectrum                    0.00             1.00          0.00
# Synthwave Saints                  0.40             1.00          1.00
# Golden Ember                      1.00             0.20          0.80
# Mystic Rhythms                    0.00             1.00          0.20
# Nightfall Sonata                  1.00             1.00          0.20
# Velvet Underground                0.80             0.00          0.65
# Astral Tide                       0.90             0.80          0.90
# The Sonic Drifters                0.65             1.00          0.65
# Celestial Voyage                  1.00             0.00          1.00
# Quantum Beat                      0.40             0.00          0.40
# Electric Serpents                 1.00             0.65          1.00
# Shadow Cadence                    0.20             0.20          0.00
# Rhythm Alchemy                    0.00             1.00          0.00
# Cloud Nine Collective             0.00             0.65          0.20
# Hypnotic Echoes                   0.00             0.00          0.00
# The Polyrhythm Syndicate          0.20             0.20          0.50
# Harmonic Dissonance               0.65             0.90          0.65
# Turbo Vortex                      0.65             0.20          0.15
# The Jazz Nomads                   0.20             0.20          0.50
# The Bassline Architects           0.00             0.40          0.40
# Cosmic Frequency                  0.20             1.00          1.00
# Parallel Dimension                1.00             0.00          1.00
#
#                           Aurora Skies  Static Mirage  Crimson Harmony  \
# Midnight Echo                     0.80           1.00             0.20
# Solar Flare                       0.00           1.00             0.00
# Velvet Pulse                      0.65           1.00             0.50
# Neon Reverie                      0.20           1.00             0.00
# The Silver Owls                   0.00           1.00             0.90
# Echo Chamber                      0.50           1.00             0.80
# Aurora Skies                      0.00           1.00             1.00
# Static Mirage                     1.00           0.00             0.20
# Crimson Harmony                   1.00           0.20             0.00
# Deep Resonance                    0.40           0.20             0.00
# The Wandering Notes               0.20           0.20             0.20
# Phantom Groove                    0.40           0.20             0.00
# Blue Horizon                      1.00           0.80             0.65
# Lunar Spectrum                    0.40           1.00             0.20
# Synthwave Saints                  0.00           1.00             0.00
# Golden Ember                      0.20           0.90             0.20
# Mystic Rhythms                    0.65           0.65             1.00
# Nightfall Sonata                  0.00           0.80             1.00
# Velvet Underground                0.15           1.00             0.15
# Astral Tide                       0.70           0.00             0.20
# The Sonic Drifters                0.00           1.00             0.40
# Celestial Voyage                  0.70           1.00             0.65
# Quantum Beat                      0.40           0.20             0.50
# Electric Serpents                 0.70           1.00             0.00
# Shadow Cadence                    0.80           0.20             0.00
# Rhythm Alchemy                    0.00           1.00             0.00
# Cloud Nine Collective             1.00           0.80             0.40
# Hypnotic Echoes                   1.00           0.90             0.65
# The Polyrhythm Syndicate          0.20           0.65             0.00
# Harmonic Dissonance               0.80           0.00             0.90
# Turbo Vortex                      0.65           1.00             0.15
# The Jazz Nomads                   0.20           0.40             1.00
# The Bassline Architects           1.00           0.50             1.00
# Cosmic Frequency                  0.20           1.00             0.65
# Parallel Dimension                0.50           0.20             0.15
#
#                           Deep Resonance  ...  Rhythm Alchemy  \
# Midnight Echo                       0.50  ...            0.20
# Solar Flare                         0.65  ...            0.20
# Velvet Pulse                        1.00  ...            1.00
# Neon Reverie                        1.00  ...            0.00
# The Silver Owls                     0.00  ...            1.00
# Echo Chamber                        0.65  ...            0.00
# Aurora Skies                        0.40  ...            0.00
# Static Mirage                       0.20  ...            1.00
# Crimson Harmony                     0.00  ...            0.00
# Deep Resonance                      0.00  ...            0.90
# The Wandering Notes                 1.00  ...            0.90
# Phantom Groove                      0.00  ...            0.20
# Blue Horizon                        0.20  ...            0.00
# Lunar Spectrum                      0.20  ...            0.80
# Synthwave Saints                    0.20  ...            0.00
# Golden Ember                        0.40  ...            1.00
# Mystic Rhythms                      0.70  ...            0.65
# Nightfall Sonata                    0.50  ...            1.00
# Velvet Underground                  0.00  ...            0.20
# Astral Tide                         0.00  ...            0.50
# The Sonic Drifters                  0.00  ...            0.80
# Celestial Voyage                    0.20  ...            0.40
# Quantum Beat                        1.00  ...            0.00
# Electric Serpents                   0.65  ...            0.15
# Shadow Cadence                      1.00  ...            1.00
# Rhythm Alchemy                      0.90  ...            0.00
# Cloud Nine Collective               0.50  ...            0.80
# Hypnotic Echoes                     0.20  ...            0.40
# The Polyrhythm Syndicate            1.00  ...            1.00
# Harmonic Dissonance                 0.70  ...            0.70
# Turbo Vortex                        1.00  ...            0.65
# The Jazz Nomads                     1.00  ...            1.00
# The Bassline Architects             0.50  ...            0.00
# Cosmic Frequency                    0.00  ...            0.00
# Parallel Dimension                  0.20  ...            0.20
#
#                           Cloud Nine Collective  Hypnotic Echoes  \
# Midnight Echo                              0.80             1.00
# Solar Flare                                0.65             0.00
# Velvet Pulse                               1.00             0.40
# Neon Reverie                               0.00             0.00
# The Silver Owls                            0.65             0.00
# Echo Chamber                               0.20             0.00
# Aurora Skies                               1.00             1.00
# Static Mirage                              0.80             0.90
# Crimson Harmony                            0.40             0.65
# Deep Resonance                             0.50             0.20
# The Wandering Notes                        0.65             0.65
# Phantom Groove                             0.00             0.20
# Blue Horizon                               1.00             1.00
# Lunar Spectrum                             0.80             1.00
# Synthwave Saints                           0.80             1.00
# Golden Ember                               0.90             0.90
# Mystic Rhythms                             0.20             0.00
# Nightfall Sonata                           0.00             0.65
# Velvet Underground                         0.80             1.00
# Astral Tide                                0.00             0.40
# The Sonic Drifters                         0.80             0.90
# Celestial Voyage                           0.00             0.00
# Quantum Beat                               0.15             0.20
# Electric Serpents                          0.15             1.00
# Shadow Cadence                             0.00             0.15
# Rhythm Alchemy                             0.80             0.40
# Cloud Nine Collective                      0.00             0.65
# Hypnotic Echoes                            0.65             0.00
# The Polyrhythm Syndicate                   0.20             0.20
# Harmonic Dissonance                        0.20             0.00
# Turbo Vortex                               1.00             1.00
# The Jazz Nomads                            1.00             0.65
# The Bassline Architects                    0.20             1.00
# Cosmic Frequency                           0.40             1.00
# Parallel Dimension                         0.50             0.00
#
#                           The Polyrhythm Syndicate  Harmonic Dissonance  \
# Midnight Echo                                 1.00                 0.65
# Solar Flare                                   0.65                 0.40
# Velvet Pulse                                  1.00                 0.70
# Neon Reverie                                  0.20                 0.65
# The Silver Owls                               0.20                 0.90
# Echo Chamber                                  0.50                 0.65
# Aurora Skies                                  0.20                 0.80
# Static Mirage                                 0.65                 0.00
# Crimson Harmony                               0.00                 0.90
# Deep Resonance                                1.00                 0.70
# The Wandering Notes                           0.90                 0.50
# Phantom Groove                                0.00                 0.00
# Blue Horizon                                  0.20                 0.00
# Lunar Spectrum                                0.20                 0.00
# Synthwave Saints                              0.50                 0.20
# Golden Ember                                  0.00                 0.20
# Mystic Rhythms                                0.80                 1.00
# Nightfall Sonata                              0.80                 1.00
# Velvet Underground                            0.00                 0.00
# Astral Tide                                   1.00                 0.65
# The Sonic Drifters                            0.40                 0.00
# Celestial Voyage                              0.00                 0.20
# Quantum Beat                                  0.65                 0.00
# Electric Serpents                             0.50                 0.50
# Shadow Cadence                                1.00                 0.50
# Rhythm Alchemy                                1.00                 0.70
# Cloud Nine Collective                         0.20                 0.20
# Hypnotic Echoes                               0.20                 0.00
# The Polyrhythm Syndicate                      0.00                 0.50
# Harmonic Dissonance                           0.50                 0.00
# Turbo Vortex                                  0.00                 1.00
# The Jazz Nomads                               0.90                 0.00
# The Bassline Architects                       0.40                 0.20
# Cosmic Frequency                              0.00                 0.20
# Parallel Dimension                            0.00                 0.20
#
#                           Turbo Vortex  The Jazz Nomads  \
# Midnight Echo                     1.00             0.40
# Solar Flare                       0.40             0.40
# Velvet Pulse                      0.00             1.00
# Neon Reverie                      0.65             0.20
# The Silver Owls                   0.20             0.20
# Echo Chamber                      0.15             0.50
# Aurora Skies                      0.65             0.20
# Static Mirage                     1.00             0.40
# Crimson Harmony                   0.15             1.00
# Deep Resonance                    1.00             1.00
# The Wandering Notes               0.20             0.90
# Phantom Groove                    1.00             0.00
# Blue Horizon                      0.00             0.00
# Lunar Spectrum                    1.00             0.00
# Synthwave Saints                  0.90             0.00
# Golden Ember                      1.00             0.00
# Mystic Rhythms                    0.20             0.00
# Nightfall Sonata                  0.00             0.65
# Velvet Underground                1.00             0.15
# Astral Tide                       0.40             0.00
# The Sonic Drifters                1.00             1.00
# Celestial Voyage                  0.00             0.00
# Quantum Beat                      1.00             1.00
# Electric Serpents                 0.00             0.00
# Shadow Cadence                    1.00             0.90
# Rhythm Alchemy                    0.65             1.00
# Cloud Nine Collective             1.00             1.00
# Hypnotic Echoes                   1.00             0.65
# The Polyrhythm Syndicate          0.00             0.90
# Harmonic Dissonance               1.00             0.00
# Turbo Vortex                      0.00             0.65
# The Jazz Nomads                   0.65             0.00
# The Bassline Architects           0.40             0.00
# Cosmic Frequency                  0.90             0.20
# Parallel Dimension                0.40             0.20
#
#                           The Bassline Architects  Cosmic Frequency  \
# Midnight Echo                                0.40              1.00
# Solar Flare                                  0.00              0.00
# Velvet Pulse                                 0.15              1.00
# Neon Reverie                                 0.00              0.20
# The Silver Owls                              0.40              1.00
# Echo Chamber                                 0.40              1.00
# Aurora Skies                                 1.00              0.20
# Static Mirage                                0.50              1.00
# Crimson Harmony                              1.00              0.65
# Deep Resonance                               0.50              0.00
# The Wandering Notes                          0.15              0.15
# Phantom Groove                               1.00              0.65
# Blue Horizon                                 0.20              0.65
# Lunar Spectrum                               1.00              1.00
# Synthwave Saints                             0.65              0.90
# Golden Ember                                 0.40              1.00
# Mystic Rhythms                               0.00              0.00
# Nightfall Sonata                             0.20              0.40
# Velvet Underground                           0.00              1.00
# Astral Tide                                  0.40              0.40
# The Sonic Drifters                           1.00              1.00
# Celestial Voyage                             0.65              0.00
# Quantum Beat                                 0.90              0.00
# Electric Serpents                            0.15              0.65
# Shadow Cadence                               0.50              0.40
# Rhythm Alchemy                               0.00              0.00
# Cloud Nine Collective                        0.20              0.40
# Hypnotic Echoes                              1.00              1.00
# The Polyrhythm Syndicate                     0.40              0.00
# Harmonic Dissonance                          0.20              0.20
# Turbo Vortex                                 0.40              0.90
# The Jazz Nomads                              0.00              0.20
# The Bassline Architects                      0.00              1.00
# Cosmic Frequency                             1.00              0.00
# Parallel Dimension                           0.90              0.00
#
#                           Parallel Dimension
# Midnight Echo                           0.20
# Solar Flare                             1.00
# Velvet Pulse                            0.40
# Neon Reverie                            1.00
# The Silver Owls                         0.00
# Echo Chamber                            1.00
# Aurora Skies                            0.50
# Static Mirage                           0.20
# Crimson Harmony                         0.15
# Deep Resonance                          0.20
# The Wandering Notes                     0.00
# Phantom Groove                          0.80
# Blue Horizon                            0.70
# Lunar Spectrum                          0.50
# Synthwave Saints                        0.80
# Golden Ember                            0.20
# Mystic Rhythms                          0.00
# Nightfall Sonata                        0.20
# Velvet Underground                      1.00
# Astral Tide                             1.00
# The Sonic Drifters                      0.00
# Celestial Voyage                        0.90
# Quantum Beat                            0.80
# Electric Serpents                       1.00
# Shadow Cadence                          0.65
# Rhythm Alchemy                          0.20
# Cloud Nine Collective                   0.50
# Hypnotic Echoes                         0.00
# The Polyrhythm Syndicate                0.00
# Harmonic Dissonance                     0.20
# Turbo Vortex                            0.40
# The Jazz Nomads                         0.20
# The Bassline Architects                 0.90
# Cosmic Frequency                        0.00
# Parallel Dimension                      0.00
#
# [35 rows x 35 columns]

# %% [markdown]
# ## Generating Random Solution

# %%
num_artists = len(artists)
num_conflict_rows, num_conflict_cols = conflict_matrix.shape

# Ensure the number of artists matches the expected total
expected_artists = 5 * 7  # 5 stages x 7 slots
consistency_check = (num_artists == expected_artists and 
                     num_conflict_rows == expected_artists and 
                     num_conflict_cols == expected_artists)

# Ensure conflict matrix aligns with artist names
artist_names_match = list(artists['name']) == list(conflict_matrix.columns)

consistency_check, artist_names_match
# Out:
# (True, True)

# %%
artist_indices = list(range(35))
random.shuffle(artist_indices)
lineup = np.array(artist_indices).reshape((5, 7))  

# Helper functions
def get_prime_slot_popularity(lineup):
    prime_artists = [lineup[stage][-1] for stage in range(5)]
    total_popularity = sum(artists.iloc[artist]['popularity'] for artist in prime_artists)
    max_possible = 5 * 100  # Max popularity (100) in each of 5 prime slots
    return total_popularity / max_possible

def get_genre_diversity_score(lineup):
    genres = artists['genre'].unique()
    max_unique = len(genres)
    total_score = 0

    for slot in range(7):
        genres_in_slot = set()
        for stage in range(5):
            artist_index = lineup[stage][slot]
            genres_in_slot.add(artists.iloc[artist_index]['genre'])
        total_score += len(genres_in_slot) / max_unique
    
    return total_score / 7  # Average over all slots

def get_conflict_penalty_score(lineup):
    worst_conflict = 0
    actual_conflict = 0

    for slot in range(7):
        artists_in_slot = [lineup[stage][slot] for stage in range(5)]
        for i in range(5):
            for j in range(i + 1, 5):
                a_i = artists.iloc[artists_in_slot[i]]['name']
                a_j = artists.iloc[artists_in_slot[j]]['name']
                conflict = conflict_matrix.at[a_i, a_j]
                actual_conflict += conflict
                worst_conflict += 1  # worst case: all conflicts = 1

    normalized_conflict = actual_conflict / worst_conflict if worst_conflict else 0
    return 1 - normalized_conflict  # because conflict is a penalty
    
lineup_tuple = (
    (3, 17, 23, 34, 31, 16,  9),
    (25,  2, 24, 10, 30, 15, 26),
    (22, 14, 18,  6,  7, 28,  5),
    (29, 19, 11, 32, 27, 13, 21),
    (33, 12,  4,  0,  8,  1, 20)
)

# Compute scores
prime_score = get_prime_slot_popularity(lineup_tuple)
genre_score = get_genre_diversity_score(lineup_tuple)
conflict_score = get_conflict_penalty_score(lineup_tuple)

# Final fitness (average of normalized scores)
fitness = (prime_score + genre_score + conflict_score) / 3

lineup_tuple, {
    'Prime Slot Popularity': round(float(prime_score),4),
    'Genre Diversity': round(float(genre_score),4),
    'Conflict Penalty': round(float(conflict_score),4),
    'Final Fitness': round(float(fitness),4)
}
# Out:
# (((3, 17, 23, 34, 31, 16, 9),
#   (25, 2, 24, 10, 30, 15, 26),
#   (22, 14, 18, 6, 7, 28, 5),
#   (29, 19, 11, 32, 27, 13, 21),
#   (33, 12, 4, 0, 8, 1, 20)),
#  {'Prime Slot Popularity': 0.936,
#   'Genre Diversity': 0.7381,
#   'Conflict Penalty': 0.6193,
#   'Final Fitness': 0.7645})

# %% [markdown]
# ### Artist Line up Class

# %%
class ArtistLineupSolution:
    def __init__(self, lineup=None):
        if lineup is not None:
            self.lineup = lineup
        else:
            artist_indices = list(range(35))
            random.shuffle(artist_indices)
            self.lineup = np.array(artist_indices).reshape((5, 7))

    def fitness(self):
        def get_prime_slot_popularity():
            prime_artists = [self.lineup[stage, -1] for stage in range(5)]
            total_popularity = sum(artists.iloc[artist]['popularity'] for artist in prime_artists)
            return total_popularity / (5 * 100)

        def get_genre_diversity_score():
            genres = artists['genre'].unique()
            total_score = 0
            for slot in range(7):
                genres_in_slot = set()
                for stage in range(5):
                    artist_index = self.lineup[stage][slot]
                    genres_in_slot.add(artists.iloc[artist_index]['genre'])
                total_score += len(genres_in_slot) / len(genres)
            return total_score / 7

        def get_conflict_penalty_score():
            actual_conflict = 0
            worst_conflict = 0
            for slot in range(7):
                artists_in_slot = [self.lineup[stage][slot] for stage in range(5)]
                for i in range(5):
                    for j in range(i + 1, 5):
                        a_i = artists.iloc[artists_in_slot[i]]['name']
                        a_j = artists.iloc[artists_in_slot[j]]['name']
                        actual_conflict += conflict_matrix.at[a_i, a_j]
                        worst_conflict += 1
            return 1 - (actual_conflict / worst_conflict if worst_conflict else 0)

        return (get_prime_slot_popularity() + get_genre_diversity_score() + get_conflict_penalty_score()) / 3

# %% [markdown]
# ### Mutation Functions

# %%
# Mutation functions
def swap_mutation(individual):
    lineup = individual.lineup
    a, b = random.sample(range(35), 2)
    pos_a = np.argwhere(lineup == a)[0]
    pos_b = np.argwhere(lineup == b)[0]
    lineup[pos_a[0], pos_a[1]], lineup[pos_b[0], pos_b[1]] = lineup[pos_b[0], pos_b[1]], lineup[pos_a[0], pos_a[1]]

def scramble_mutation(individual):
    lineup = individual.lineup.flatten()
    idx = sorted(random.sample(range(35), 5))
    scrambled = [lineup[i] for i in idx]
    random.shuffle(scrambled)
    for i, val in zip(idx, scrambled):
        lineup[i] = val
    individual.lineup = lineup.reshape((5, 7))

def inversion_mutation(individual):
    lineup = individual.lineup.flatten()
    a, b = sorted(random.sample(range(35), 2))
    lineup[a:b+1] = lineup[a:b+1][::-1]
    individual.lineup = lineup.reshape((5, 7))

# %%
def displacement_mutation(individual):
    lineup = individual.lineup.flatten().tolist()
    a, b = sorted(random.sample(range(len(lineup)), 2))
    segment = lineup[a:b+1]
    del lineup[a:b+1]
    insert_at = random.randint(0, len(lineup))
    lineup = lineup[:insert_at] + segment + lineup[insert_at:]
    individual.lineup = np.array(lineup).reshape(5, 7)

# %%
def heuristic_mutation(individual):
    worst_slot = -1
    worst_score = -1
    for slot in range(7):
        conflict = 0
        for i in range(5):
            for j in range(i + 1, 5):
                a = individual.lineup[i, slot]
                b = individual.lineup[j, slot]
                conflict += conflict_matrix.iat[a, b]
        if conflict > worst_score:
            worst_score = conflict
            worst_slot = slot
    if worst_slot != -1:
        # Swap first two in worst slot
        individual.lineup[0, worst_slot], individual.lineup[1, worst_slot] = individual.lineup[1, worst_slot], individual.lineup[0, worst_slot]

# %% [markdown]
# ### Crossover Functions

# %%
def cycle_crossover_wrapper(p1, p2):
    parent1 = p1.lineup.flatten()
    parent2 = p2.lineup.flatten()
    size = len(parent1)
    child1 = [-1] * size
    child2 = [-1] * size
    indices = list(range(size))
    cycle = 0

    while -1 in child1:
        idx = indices[child1.index(-1)]
        val = parent1[idx]
        start = idx
        while True:
            child1[start] = parent1[start] if cycle % 2 == 0 else parent2[start]
            child2[start] = parent2[start] if cycle % 2 == 0 else parent1[start]
            start = parent1.tolist().index(parent2[start])
            if start == idx:
                break
        cycle += 1

    return ArtistLineupSolution(np.array(child1).reshape(5, 7)), ArtistLineupSolution(np.array(child2).reshape(5, 7))

# %%
def order_crossover_wrapper(p1, p2):
    parent1 = p1.lineup.flatten().tolist()
    parent2 = p2.lineup.flatten().tolist()
    size = len(parent1)
    a, b = sorted(random.sample(range(size), 2))

    def order_crossover(p1, p2):
        child = [-1]*size
        child[a:b+1] = p1[a:b+1]
        fill = [item for item in p2 if item not in child]
        idx = 0
        for i in range(size):
            if child[i] == -1:
                child[i] = fill[idx]
                idx += 1
        return child

    child1 = order_crossover(parent1, parent2)
    child2 = order_crossover(parent2, parent1)
    return ArtistLineupSolution(np.array(child1).reshape(5, 7)), ArtistLineupSolution(np.array(child2).reshape(5, 7))

# %%
def pmx_crossover_wrapper(p1, p2):
    parent1 = p1.lineup.flatten()
    parent2 = p2.lineup.flatten()
    size = len(parent1)
    cx_point1, cx_point2 = sorted(random.sample(range(size), 2))

    def pmx(parent_a, parent_b):
        child = [-1] * size
        child[cx_point1:cx_point2+1] = parent_a[cx_point1:cx_point2+1]
        for i in range(cx_point1, cx_point2+1):
            if parent_b[i] not in child:
                pos = i
                while child[pos] != -1:
                    pos = parent_b.tolist().index(parent_a[pos])
                child[pos] = parent_b[i]
        for i in range(size):
            if child[i] == -1:
                child[i] = parent_b[i]
        return child

    child1 = pmx(parent1, parent2)
    child2 = pmx(parent2, parent1)
    return ArtistLineupSolution(np.array(child1).reshape(5, 7)), ArtistLineupSolution(np.array(child2).reshape(5, 7))

# %% [markdown]
# ### Selection Functions

# %%
def tournament_selection(population, k=3):
    selected = random.sample(population, k)
    return max(selected, key=lambda x: x.fitness()), max(random.sample(population, k), key=lambda x: x.fitness())

# %%
def roulette_selection(population):
    total_fitness = sum(p.fitness() for p in population)
    probs = [p.fitness() / total_fitness for p in population]
    return np.random.choice(population, p=probs), np.random.choice(population, p=probs)

# %%
def rank_selection(population):
    sorted_pop = sorted(population, key=lambda x: x.fitness())
    ranks = list(range(1, len(population) + 1))
    total = sum(ranks)
    probs = [rank / total for rank in ranks]
    return np.random.choice(sorted_pop, p=probs), np.random.choice(sorted_pop, p=probs)

# %% [markdown]
# ### Genetic Algorithm

# %%
class GeneticAlgorithm:
    def __init__(self, selection_functions, mutation_functions, crossover_functions,
                 population_size=50, generations=100):
        self.selection_functions = selection_functions
        self.mutation_functions = mutation_functions
        self.crossover_functions = crossover_functions
        self.population_size = population_size
        self.generations = generations

    def run(self):
        population = [ArtistLineupSolution() for _ in range(self.population_size)]
        best_solution = max(population, key=lambda x: x.fitness())

        for gen in range(self.generations):
            new_population = []
            for _ in range(self.population_size // 2):
                selection = random.choice(self.selection_functions)
                parent1, parent2 = selection(population)
                crossover = random.choice(self.crossover_functions)
                child1, child2 = crossover(parent1, parent2)

                random.choice(self.mutation_functions)(child1)
                random.choice(self.mutation_functions)(child2)

                new_population.extend([child1, child2])

            population = new_population
            best_in_gen = max(population, key=lambda x: x.fitness())
            if best_in_gen.fitness() > best_solution.fitness():
                best_solution = best_in_gen

            print(f"Gen {gen + 1}: Best Fitness = {round(best_solution.fitness(), 4)}")

        return best_solution

# %%
if __name__ == "__main__":
    ga = GeneticAlgorithm(
        selection_functions=[tournament_selection, roulette_selection],
        mutation_functions=[swap_mutation, scramble_mutation, inversion_mutation],
        crossover_functions=[cycle_crossover_wrapper, pmx_crossover_wrapper],
        population_size=50,
        generations=100
    )

    best = ga.run()
    print("Best lineup:")
    print(best.lineup)
    print("Fitness Score:", round(best.fitness(), 4))
# Out:
# Gen 1: Best Fitness = 0.712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 10
#       1 if __name__ == "__main__":
#       2     ga = GeneticAlgorithm(
#       3         selection_functions=[tournament_selection, roulette_selection],
#       4         mutation_functions=[swap_mutation, scramble_mutation, inversion_mutation],
#    (...)
#       7         generations=100
#       8     )
# ---> 10     best = ga.run()
#      11     print("Best lineup:")
#      12     print(best.lineup)
#
# Cell In[36], line 18, in GeneticAlgorithm.run(self)
#      16 for _ in range(self.population_size // 2):
#      17     selection = random.choice(self.selection_functions)
# ---> 18     parent1, parent2 = selection(population)
#      19     crossover = random.choice(self.crossover_functions)
#      20     child1, child2 = crossover(parent1, parent2)
#
# Cell In[34], line 2, in roulette_selection(population)
#       1 def roulette_selection(population):
# ----> 2     total_fitness = sum(p.fitness() for p in population)
#       3     probs = [p.fitness() / total_fitness for p in population]
#       4     return np.random.choice(population, p=probs), np.random.choice(population, p=probs)
#
# Cell In[34], line 2, in <genexpr>(.0)
#       1 def roulette_selection(population):
# ----> 2     total_fitness = sum(p.fitness() for p in population)
#       3     probs = [p.fitness() / total_fitness for p in population]
#       4     return np.random.choice(population, p=probs), np.random.choice(population, p=probs)
#
# Cell In[26], line 40, in ArtistLineupSolution.fitness(self)
#      37                 worst_conflict += 1
#      38     return 1 - (actual_conflict / worst_conflict if worst_conflict else 0)
# ---> 40 return (get_prime_slot_popularity() + get_genre_diversity_score() + get_conflict_penalty_score()) / 3
#
# Cell In[26], line 35, in ArtistLineupSolution.fitness.<locals>.get_conflict_penalty_score()
#      33 for j in range(i + 1, 5):
#      34     a_i = artists.iloc[artists_in_slot[i]]['name']
# ---> 35     a_j = artists.iloc[artists_in_slot[j]]['name']
#      36     actual_conflict += conflict_matrix.at[a_i, a_j]
#      37     worst_conflict += 1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1754, in _iLocIndexer._getitem_axis(self, key, axis)
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
# -> 1754 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3996, in DataFrame._ixs(self, i, axis)
#    3994 # irow
#    3995 if axis == 0:
# -> 3996     new_mgr = self._mgr.fast_xs(i)
#    3998     # if we are a copy, mark as such
#    3999     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1010, in BlockManager.fast_xs(self, loc)
#    1008 bp = BlockPlacement(slice(0, len(result)))
#    1009 block = new_block(result, placement=bp, ndim=1)
# -> 1010 return SingleBlockManager(block, self.axes[0])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1837, in SingleBlockManager.__init__(self, block, axis, verify_integrity)
#    1834 __slots__ = ()
#    1835 is_single_block = True
# -> 1837 def __init__(
#    1838     self,
#    1839     block: Block,
#    1840     axis: Index,
#    1841     verify_integrity: bool = False,
#    1842 ) -> None:
#    1843     # Assertions disabled for performance
#    1844     # assert isinstance(block, Block), type(block)
#    1845     # assert isinstance(axis, Index), type(axis)
#    1847     self.axes = [axis]
#    1848     self.blocks = (block,)
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    ga = GeneticAlgorithm(
        selection_functions=[tournament_selection, roulette_selection, rank_selection],
        mutation_functions=[swap_mutation, scramble_mutation, inversion_mutation, displacement_mutation, heuristic_mutation],
        crossover_functions=[cycle_crossover_wrapper, pmx_crossover_wrapper, order_crossover_wrapper],
        population_size=50,
        generations=100
    )

    best = ga.run()
    print("Best lineup:")
    print(best.lineup)
    print("Fitness Score:", round(best.fitness(), 4))
# Out:
# Gen 1: Best Fitness = 0.7251
# Gen 2: Best Fitness = 0.7251
# Gen 3: Best Fitness = 0.7251
# Gen 4: Best Fitness = 0.7251
# Gen 5: Best Fitness = 0.7251
# Gen 6: Best Fitness = 0.7251
# Gen 7: Best Fitness = 0.7339
# Gen 8: Best Fitness = 0.7339
# Gen 9: Best Fitness = 0.7339
# Gen 10: Best Fitness = 0.7339
# Gen 11: Best Fitness = 0.7339
# Gen 12: Best Fitness = 0.7339
# Gen 13: Best Fitness = 0.7456
# Gen 14: Best Fitness = 0.7456
# Gen 15: Best Fitness = 0.7456
# Gen 16: Best Fitness = 0.7456
# Gen 17: Best Fitness = 0.7456
# Gen 18: Best Fitness = 0.7456
# Gen 19: Best Fitness = 0.7456
# Gen 20: Best Fitness = 0.7456
# Gen 21: Best Fitness = 0.7456
# Gen 22: Best Fitness = 0.7456
# Gen 23: Best Fitness = 0.7456
# Gen 24: Best Fitness = 0.7456
# Gen 25: Best Fitness = 0.7456
# Gen 26: Best Fitness = 0.7456
# Gen 27: Best Fitness = 0.7456
# Gen 28: Best Fitness = 0.7456
# Gen 29: Best Fitness = 0.7456
# Gen 30: Best Fitness = 0.7456
# Gen 31: Best Fitness = 0.7463
# Gen 32: Best Fitness = 0.7463
# Gen 33: Best Fitness = 0.7463
# Gen 34: Best Fitness = 0.7463
# Gen 35: Best Fitness = 0.7463
# Gen 36: Best Fitness = 0.7463
# Gen 37: Best Fitness = 0.7463
# Gen 38: Best Fitness = 0.7463
# Gen 39: Best Fitness = 0.7463
# Gen 40: Best Fitness = 0.7463
# Gen 41: Best Fitness = 0.7463
# Gen 42: Best Fitness = 0.7463
# Gen 43: Best Fitness = 0.7463
# Gen 44: Best Fitness = 0.7463
# Gen 45: Best Fitness = 0.7463
# Gen 46: Best Fitness = 0.7463
# Gen 47: Best Fitness = 0.7463
# Gen 48: Best Fitness = 0.7463
# Gen 49: Best Fitness = 0.7463
# Gen 50: Best Fitness = 0.7463
# Gen 51: Best Fitness = 0.7463
# Gen 52: Best Fitness = 0.7463
# Gen 53: Best Fitness = 0.7463
# Gen 54: Best Fitness = 0.7463
# Gen 55: Best Fitness = 0.7463
# Gen 56: Best Fitness = 0.7463
# Gen 57: Best Fitness = 0.7463
# Gen 58: Best Fitness = 0.7463
# Gen 59: Best Fitness = 0.7463
# Gen 60: Best Fitness = 0.7463
# Gen 61: Best Fitness = 0.7463
# Gen 62: Best Fitness = 0.7463
# Gen 63: Best Fitness = 0.7463
# Gen 64: Best Fitness = 0.7463
# Gen 65: Best Fitness = 0.7463
# Gen 66: Best Fitness = 0.7463
# Gen 67: Best Fitness = 0.7463
# Gen 68: Best Fitness = 0.7463
# Gen 69: Best Fitness = 0.7463
# Gen 70: Best Fitness = 0.7463
# Gen 71: Best Fitness = 0.7463
# Gen 72: Best Fitness = 0.7463
# Gen 73: Best Fitness = 0.7463
# Gen 74: Best Fitness = 0.7463
# Gen 75: Best Fitness = 0.7463
# Gen 76: Best Fitness = 0.7463
# Gen 77: Best Fitness = 0.7463
# Gen 78: Best Fitness = 0.7463
# Gen 79: Best Fitness = 0.7463
# Gen 80: Best Fitness = 0.7463
# Gen 81: Best Fitness = 0.7463
# Gen 82: Best Fitness = 0.7463
# Gen 83: Best Fitness = 0.7463
# Gen 84: Best Fitness = 0.7463
# Gen 85: Best Fitness = 0.7469
# Gen 86: Best Fitness = 0.7469
# Gen 87: Best Fitness = 0.7469
# Gen 88: Best Fitness = 0.7469
# Gen 89: Best Fitness = 0.7469
# Gen 90: Best Fitness = 0.7469
# Gen 91: Best Fitness = 0.7469
# Gen 92: Best Fitness = 0.7469
# Gen 93: Best Fitness = 0.7469
# Gen 94: Best Fitness = 0.7469
# Gen 95: Best Fitness = 0.7469
# Gen 96: Best Fitness = 0.7469
# Gen 97: Best Fitness = 0.7469
# Gen 98: Best Fitness = 0.7469
# Gen 99: Best Fitness = 0.7469
# Gen 100: Best Fitness = 0.7469
# Best lineup:
# [[ 3  0 24 15  2 27 14]
#  [18 34 26  5  1  7 25]
#  [29 10 19 17 21 28 22]
#  [11 20 16  4 30  8 23]
#  [ 9 31 13 12 32 33  6]]
# Fitness Score: 0.7469

# %%
'''
Best lineup:
[[ 3 17 23 34 31 16  9]
 [25  2 24 10 30 15 26]
 [22 14 18  6  7 28  5]
 [29 19 11 32 27 13 21]
 [33 12  4  0  8  1 20]]
Fitness Score: 0.7645
'''

# %%
import numpy as np
import pandas as pd
import random
import math

# Assume these are already defined:
# artists (DataFrame with columns: name, popularity, genre)
# conflict_matrix (DataFrame: index and columns are artist names with conflict values)

class ArtistLineupSolution:
    def __init__(self, lineup=None):
        if lineup is not None:
            self.lineup = lineup
        else:
            artist_indices = list(range(35))
            random.shuffle(artist_indices)
            self.lineup = np.array(artist_indices).reshape((5, 7))

    def fitness(self):
        def get_prime_slot_popularity():
            prime_artists = [self.lineup[stage, -1] for stage in range(5)]
            total_popularity = sum(artists.iloc[artist]['popularity'] for artist in prime_artists)
            return total_popularity / (5 * 100)

        def get_genre_diversity_score():
            genres = artists['genre'].unique()
            total_score = 0
            for slot in range(7):
                genres_in_slot = set()
                for stage in range(5):
                    artist_index = self.lineup[stage][slot]
                    genres_in_slot.add(artists.iloc[artist_index]['genre'])
                total_score += len(genres_in_slot) / len(genres)
            return total_score / 7

        def get_conflict_penalty_score():
            actual_conflict = 0
            worst_conflict = 0
            for slot in range(7):
                artists_in_slot = [self.lineup[stage][slot] for stage in range(5)]
                for i in range(5):
                    for j in range(i + 1, 5):
                        a_i = artists.iloc[artists_in_slot[i]]['name']
                        a_j = artists.iloc[artists_in_slot[j]]['name']
                        actual_conflict += conflict_matrix.at[a_i, a_j]
                        worst_conflict += 1
            return 1 - (actual_conflict / worst_conflict if worst_conflict else 0)

        return (get_prime_slot_popularity() + get_genre_diversity_score() + get_conflict_penalty_score()) / 3

    def mutate(self):
        a, b = random.sample(range(35), 2)
        pos_a = np.argwhere(self.lineup == a)[0]
        pos_b = np.argwhere(self.lineup == b)[0]
        self.lineup[pos_a[0], pos_a[1]], self.lineup[pos_b[0], pos_b[1]] = self.lineup[pos_b[0], pos_b[1]], self.lineup[pos_a[0], pos_a[1]]

    def copy(self):
        return ArtistLineupSolution(np.copy(self.lineup))

    
    def __str__(self):
        return f"Lineup:\n{self.lineup}\nFitness: {self.fitness():.4f}"

def hill_climbing(max_iterations=1000):
    current = ArtistLineupSolution()
    current_fitness = current.fitness()
    for _ in range(max_iterations):
        neighbor = current.copy()
        neighbor.mutate()
        neighbor_fitness = neighbor.fitness()
        if neighbor_fitness > current_fitness:
            current, current_fitness = neighbor, neighbor_fitness
    return current

def simulated_annealing(initial_temp=100, cooling_rate=0.99, max_iterations=1000):
    current = ArtistLineupSolution()
    current_fitness = current.fitness()
    temp = initial_temp
    for _ in range(max_iterations):
        neighbor = current.copy()
        neighbor.mutate()
        neighbor_fitness = neighbor.fitness()
        delta = neighbor_fitness - current_fitness
        if delta > 0 or random.random() < math.exp(delta / temp):
            current, current_fitness = neighbor, neighbor_fitness
        temp *= cooling_rate
    return current

# %%
solution = hill_climbing(max_iterations=1000)
print(solution)
# Out:
# Lineup:
# [[29 34 18 25 17 24  9]
#  [23 27 31  6  5 26 14]
#  [ 7 28 12 16  2 20  3]
#  [10 11 15  1 30  8 13]
#  [32  4 21 33  0 19 22]]
# Fitness: 0.8243

# %%
'''
Lineup:
[[29 34 18 25 17 24  9]
 [23 27 31  6  5 26 14]
 [ 7 28 12 16  2 20  3]
 [10 11 15  1 30  8 13]
 [32  4 21 33  0 19 22]]
Fitness: 0.8243
'''

# %%
solution = simulated_annealing(initial_temp=100, cooling_rate=0.99, max_iterations=1000)
print(solution)
# Out:
# Lineup:
# [[ 9 18 19  2 34 20 17]
#  [12  6  5 21 30 26 23]
#  [ 1 25 33  0 10  4 13]
#  [31 22 24 11  7 32 27]
#  [15  3  8 29 16 28 14]]
# Fitness: 0.7410
